# %%
# !pip install langchain
# !pip install langchain_experimental
# !pip install pandas

# %%
import pandas as pd
csv_data = pd.read_csv("./Resources/customers-100.csv")
csv_data.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# 3          Dominican Republic  001-808-617-6467x12895        +1-813-324-8756
# 4  Slovakia (Slovak Republic)  001-234-203-0635x76146  001-199-446-3860x3486
#
#                          Email Subscription Date                      Website
# 0     zunigavanessa@smith.info        2020-08-24   http://www.stephenson.com/
# 1              vmata@colon.com        2021-04-23        http://www.hobbs.com/
# 2          beckycarr@hogan.com        2020-03-25     http://www.lawrence.com/
# 3  stanleyblackwell@benson.org        2020-06-02   http://www.good-lyons.com/
# 4      colinalvarado@miles.net        2021-04-17  https://goodwin-ingram.com/

# %%
from langchain.agents.agent_types import AgentType
from langchain_experimental.agents.agent_toolkits import create_csv_agent
from langchain_openai import ChatOpenAI, OpenAI
from langchain_community.llms import GPT4All
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler
from pathlib import Path

callbacks = [StreamingStdOutCallbackHandler()]
model = GPT4All(
    model=f"{Path.home()}/Models/mistral-7b-openorca.Q4_0.gguf", 
    temp=0
    )

agent = create_csv_agent(
    model,
    "./Resources/customers-100.csv",
    verbose=True,
    agent_type=AgentType.ZERO_SHOT_REACT_DESCRIPTION
)

agent.run("How many rows are there?")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 14
#       8 callbacks = [StreamingStdOutCallbackHandler()]
#       9 model = GPT4All(
#      10     model=f"{Path.home()}/Models/mistral-7b-openorca.Q4_0.gguf",
#      11     temp=0
#      12     )
# ---> 14 agent = create_csv_agent(
#      15     model,
#      16     "./Resources/customers-100.csv",
#      17     verbose=True,
#      18     agent_type=AgentType.CHAT_ZERO_SHOT_REACT_DESCRIPTION
#      19 )
#      21 agent.run("How many rows are there?")
#
# File ~/miniconda3/envs/langchain/lib/python3.11/site-packages/langchain_experimental/agents/agent_toolkits/csv/base.py:66, in create_csv_agent(llm, path, pandas_kwargs, **kwargs)
#      64 else:
#      65     raise ValueError(f"Expected str, list, or file-like object, got {type(path)}")
# ---> 66 return create_pandas_dataframe_agent(llm, df, **kwargs)
#
# File ~/miniconda3/envs/langchain/lib/python3.11/site-packages/langchain_experimental/agents/agent_toolkits/pandas/base.py:292, in create_pandas_dataframe_agent(llm, df, agent_type, callback_manager, prefix, suffix, input_variables, verbose, return_intermediate_steps, max_iterations, max_execution_time, early_stopping_method, agent_executor_kwargs, include_df_in_prompt, number_of_head_rows, extra_tools, engine, **kwargs)
#     286         agent = RunnableMultiActionAgent(
#     287             runnable=create_openai_tools_agent(llm, tools, prompt),  # type: ignore
#     288             input_keys_arg=["input"],
#     289             return_keys_arg=["output"],
#     290         )
#     291 else:
# --> 292     raise ValueError(
#     293         f"Agent type {agent_type} not supported at the moment. Must be one of "
#     294         "'openai-tools', 'openai-functions', or 'zero-shot-react-description'."
#     295     )
#     296 return AgentExecutor(
#     297     agent=agent,
#     298     tools=tools,
#    (...)
#     305     **(agent_executor_kwargs or {}),
#     306 )
#
# ValueError: Agent type AgentType.CHAT_ZERO_SHOT_REACT_DESCRIPTION not supported at the moment. Must be one of 'openai-tools', 'openai-functions', or 'zero-shot-react-description'.
